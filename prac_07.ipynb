# %% [markdown]
# <a href="https://colab.research.google.com/github/omshahu/ML_Practicals/blob/main/prac_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME = Omprakash Shahu (CS23064)
#
# AIM= To apply support vector machine for classification and analyze the impact of different kernels on model accuracy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/ML_Class/pulsar_stars - pulsar_stars.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    Mean of the integrated profile  \
# 0                      140.562500
# 1                      102.507812
# 2                      103.015625
# 3                      136.750000
# 4                       88.726562
#
#    Standard deviation of the integrated profile  \
# 0                                     55.683782
# 1                                     58.882430
# 2                                     39.341649
# 3                                     57.178449
# 4                                     40.672225
#
#    Excess kurtosis of the integrated profile  \
# 0                                  -0.234571
# 1                                   0.465318
# 2                                   0.323328
# 3                                  -0.068415
# 4                                   0.600866
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           -0.699648                  3.199833
# ...

# %%
svc=SVC(C=100.0)
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print("Model accuracy score with default hyperparameter :")
accuracy_score(y_test,y_pred)
# Out:
# Model accuracy score with default hyperparameter :
# 0.9802607076350093

# %%
svc=SVC(C=1000.0)
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print("Model accuracy score with default hyperparameter :")
accuracy_score(y_test,y_pred)
# Out:
# Model accuracy score with default hyperparameter :
# 0.9797020484171323

# %%
linear_svc= SVC(kernel='linear',C=1.0)
linear_svc.fit(X_train,y_train)
y_pred=linear_svc.predict(X_test)
print("Model accuracy score with default hyperparameter :")
accuracy_score(y_test,y_pred)
# Out:
# Model accuracy score with default hyperparameter :
# 0.9787709497206704

# %%
linear_svc= SVC(kernel='linear',C=100.0)
linear_svc.fit(X_train,y_train)
y_pred=linear_svc.predict(X_test)
print("Model accuracy score with default hyperparameter :")
accuracy_score(y_test,y_pred)
# Out:
# Model accuracy score with default hyperparameter :
# 0.978584729981378

# %%
linear_svc= SVC(kernel='linear',C=1000.0)
linear_svc.fit(X_train,y_train)
y_pred=linear_svc.predict(X_test)
print("Model accuracy score with default hyperparameter :")
accuracy_score(y_test,y_pred)
# Out:
# Model accuracy score with default hyperparameter :
# 0.978584729981378

# %%
poly_svc= SVC(kernel='poly',C=1.0)
poly_svc.fit(X_train,y_train)
y_pred=poly_svc.predict(X_test)
print("Model accuracy score with default hyperparameter :")
accuracy_score(y_test,y_pred)
# Out:
# Model accuracy score with default hyperparameter :
# 0.9769087523277468

# %%
poly_svc= SVC(kernel='poly',C=100.0)
poly_svc.fit(X_train,y_train)
y_pred=poly_svc.predict(X_test)
print("Model accuracy score with default hyperparameter :")
accuracy_score(y_test,y_pred)
# Out:
# Model accuracy score with default hyperparameter :
# 0.9793296089385475
