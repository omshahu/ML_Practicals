# %% [markdown]
# <a href="https://colab.research.google.com/github/omshahu/ML_Practicals/blob/main/prac_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME = Omprakash Shahu (CS23064)
#
# Aim = To apply Principal Component Analysis for Dimensionality reduction and visualize the transformed features space

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
iris = load_iris()
x = iris.data
y = iris.target

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_scaled)

# %%
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.72962445 0.22850762]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x_pca[:, 0], x_pca[:,1], c=y)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization of Iris Dataset")
plt.colorbar()
plt.show()
