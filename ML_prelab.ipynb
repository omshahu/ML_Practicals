# %% [markdown]
# <a href="https://colab.research.google.com/github/omshahu/ML_Practicals/blob/main/ML_prelab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Omprakash Shahu (CS23064)
#
# Pre-Lab : Understand Google Colab and Python Libraries for Machine Learning [ Numpy,Panda, Matplotlib,Seaborn,Scikit-learn]

# %%
'Numpy'
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print("NumPy Array:", arr)

arr_plus_one = arr + 1
print("Array + 1:", arr_plus_one)
# Out:
# NumPy Array: [1 2 3 4 5]
# Array + 1: [2 3 4 5 6]

# %%
print(arr.shape)
print(arr.mean())
print(arr.std())
print(np.sum(arr))
print(np.max(arr))
# Out:
# (5,)
# 3.0
# 1.4142135623730951
# 15
# 5

# %%
x = np.array([[1,2],[3,4]])
y = np.array([[5,6],[7,8]])
print(np.dot(x,y))
print(np.transpose(x))
# Out:
# [[19 22]
#  [43 50]]
# [[1 3]
#  [2 4]]

# %%
import pandas as pd

data = {'Name': ['Amit', 'Bhupendra', 'Charu'],
        'Age': [20, 21, 19],
        'City': ['Nagpur', 'Lalit_Nagar', 'Chandigarh']}

df = pd.DataFrame(data)
print(df)
# Out:
#         Name  Age         City
# 0       Amit   20       Nagpur
# 1  Bhupendra   21  Lalit_Nagar
# 2      Charu   19   Chandigarh

# %%
print(df.shape)
# Out:
# (3, 3)

# %%
print(df.head())
# Out:
#         Name  Age         City
# 0       Amit   20       Nagpur
# 1  Bhupendra   21  Lalit_Nagar
# 2      Charu   19   Chandigarh

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None

# %%
print(df.describe())
# Out:
#         Age
# count   3.0
# mean   20.0
# std     1.0
# min    19.0
# 25%    19.5
# 50%    20.0
# 75%    20.5
# max    21.0

# %%
# Data selection
print(df['Name'])
print(df['Age'],['City'])
# Out:
# 0         Amit
# 1    Bhupendra
# 2        Charu
# Name: Name, dtype: object
# 0    20
# 1    21
# 2    19
# Name: Age, dtype: int64 ['City']

# %%
df_encoded = pd.get_dummies(df['City'])
print(df_encoded)
# Out:
#    Chandigarh  Lalit_Nagar  Nagpur
# 0       False        False    True
# 1       False         True   False
# 2        True        False   False

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('Line Plot')
plt.show()

# %%
# BAR plot
plt.bar(x,y)
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('Bar Plot')
plt.show()

# %%
import seaborn as sns

# %%
# Load sample data
data = sns.load_dataset('iris')

# %%
# Pair plot
sns.pairplot(data, hue='species')
plt.show()

# %%
#Heatmap
data = sns.load_dataset('iris') # Ensure data is the iris DataFrame
corr = data.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.show()

# %%
# Box plot
sns.boxplot(x='species', y='sepal_length', data=data)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
